# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from ExpandedBufferStock import ExpandedBufferStockClass

# %%
model = ExpandedBufferStockClass()

# %%
model.setup()

# %%
model.allocate()

# %%
model.solve()
# Out:
# Period 10:
# Keeper's problem solved in 5.0 secs
#
# Period 9:
# Post-decision computed in 4.7 secs
# Keeper's problem solved in 6.5 secs
#
# Period 8:
# Post-decision computed in 0.0 secs
# Keeper's problem solved in 0.0 secs
#
# Period 7:
# Post-decision computed in 0.0 secs
# Keeper's problem solved in 0.0 secs
#
# Period 6:
# Post-decision computed in 0.0 secs
# Keeper's problem solved in 0.0 secs
#
# Period 5:
# Post-decision computed in 0.0 secs
# Keeper's problem solved in 0.0 secs
#
# Period 4:
# Post-decision computed in 0.0 secs
# Keeper's problem solved in 0.0 secs
#
# Period 3:
# Post-decision computed in 0.0 secs
# Keeper's problem solved in 0.0 secs
#
# Period 2:
# Post-decision computed in 0.0 secs
# Keeper's problem solved in 0.0 secs
#
# Period 1:
# Post-decision computed in 0.0 secs
# Keeper's problem solved in 0.0 secs
#
# Model solved with NVFI in 16.3 secs

# %%
for t in range(model.par.T):
    plt.plot(model.par.grid_nb,model.sol.c_keep[t,:,0])
